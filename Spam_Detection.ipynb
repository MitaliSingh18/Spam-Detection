# %%
# !pip install scikit-plot
# Out:
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Installing collected packages: scikit-plot
# Successfully installed scikit-plot-0.3.7

# %%
import numpy as np
import pandas as pd
from wordcloud import WordCloud
from wordcloud import STOPWORDS
import nltk
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt
import scikitplot as skplt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer


from sklearn.metrics import accuracy_score, confusion_matrix, classification_report #класс оценок



#import methods
from sklearn.naive_bayes import MultinomialNB
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
nltk.download("stopwords")
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import os

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv("/content/drive/MyDrive/spam_data.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Show Data

# %%
df.head(11)
# Out:
#    Category                                            Message
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# 5      spam  FreeMsg Hey there darling it's been 3 week's n...
# 6       ham  Even my brother is not like to speak with me. ...
# 7       ham  As per your request 'Melle Melle (Oru Minnamin...
# 8      spam  WINNER!! As a valued network customer you have...
# 9      spam  Had your mobile 11 months or more? U R entitle...
# 10      ham  I'm gonna be home soon and i don't want to tal...

# %%
df.columns = ['Category', 'Message']
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# # Splitting the labels and the data separately

# %%
df_labels = df['Category']
df_labels.head(11)
# Out:
# 0      ham
# 1      ham
# 2     spam
# 3      ham
# 4      ham
# 5     spam
# 6      ham
# 7      ham
# 8     spam
# 9     spam
# 10     ham
# Name: Category, dtype: object

# %% [markdown]
# # Data Visualization
#  - To check the most used word in Ham sms and Spam SMS
#  - To visualize the percentage of Ham and Spam SMS

# %% [markdown]
# ## Plotting ham and spam data % in pie chart

# %%
stopwords = STOPWORDS
stopwords = list(stopwords)
STOPWORDS = nltk.corpus.stopwords.words('english')
stopwords = stopwords + STOPWORDS

ham_dataset = df[df.Category == 'ham']
spam_dataset = df[df.Category == 'spam']
ham_words = ' '
spam_words = ' '

for words in ham_dataset.Message:
    txt = words.lower()
    tokens = nltk.word_tokenize(txt)
    for word in tokens:
        ham_words = ham_words + word + " "
for words in spam_dataset.Message:
    txt = words.lower()
    tokens = nltk.word_tokenize(txt)
    for word in tokens:
        spam_words = spam_words + word + " "

def gen_wordcloud(wordcloud):
    plt.figure(figsize = (10,8))
    plt.imshow(wordcloud)
    plt.tight_layout(pad=0)
    plt.axis('off')
    plt.show()

print("\n")
print("\t\t\t\t HAM WORDS")
wordcloud = WordCloud(background_color = 'white', width = 500, height = 500, stopwords = stopwords,
                     max_words = 500, max_font_size = 50, random_state = 42).generate(ham_words)
gen_wordcloud(wordcloud)

print("\t\t\t\t SPAM WORDS")
wordcloud = WordCloud(background_color = 'white', width = 500, height = 500, stopwords = stopwords,
                     max_words = 500, max_font_size = 50, random_state = 42).generate(spam_words)
gen_wordcloud(wordcloud)
# Out:
# 				 HAM WORDS
# 				 SPAM WORDS

# %%
count_Class = pd.value_counts(df.Category, sort = True)

# Data to Plot
labels = 'Ham', 'Spam'
sizes = [count_Class[0], count_Class[1]]
colors = ['lightskyblue', 'aqua']
explode = (0.1, 0.1)

# Plot
plt.pie(sizes, explode = explode, labels = labels, colors = colors,
        autopct = '%1.1f%%', shadow = True, startangle = 90)
plt.axis('equal')
plt.show()

# %% [markdown]
# # Splitting the Test and Train Data

# %%
train_set, test_set, train_label, test_label = train_test_split(df, df_labels, test_size = 0.33, random_state = 42)
print(train_set.shape)
print(test_set.shape)
print("\nThe Trainset consists of {} records and {} features".format(train_set.shape[0],train_set.shape[1]))
print("\nThe Testset consists of {} records and {} features".format(test_set.shape[0],train_set.shape[1]))
# Out:
# (3733, 2)
# (1839, 2)
#
# The Trainset consists of 3733 records and 2 features
#
# The Testset consists of 1839 records and 2 features

# %% [markdown]
# # Extracting N-grams from the Text Data

# %%
countvect = CountVectorizer(ngram_range = (2,2), )
x_counts = countvect.fit(train_set.Message)

# preparing for training set
x_train_df = countvect.transform(train_set.Message)

# preparing for test set
x_test_df = countvect.transform(test_set.Message)

# %% [markdown]
# # Data Model
#
# The Algorithms used below in this notebooks are:
#
#  - Naive Bayes
#  - K-Nearest
#  - Decision Tree
#  - Support Vector Machine
#  - Random Forest

# %% [markdown]
# # Naive Bayes classifier

# %%
clf = MultinomialNB()
clf.fit(x_train_df,train_set.Category)
predicted_values_NB = clf.predict(x_test_df)
predictions = dict()
accuracy = accuracy_score(test_set.Category, predicted_values_NB)
predictions['Naive Bayes'] = accuracy * 100
confusionmatrix = confusion_matrix(test_set.Category, predicted_values_NB)
print("The accuracy of Naive Bayes clasifier is {}%".format(accuracy * 100))
print("\n", confusionmatrix)
skplt.metrics.plot_confusion_matrix(test_set.Category, predicted_values_NB, normalize = True)
plt.show()
# Out:
# The accuracy of Naive Bayes clasifier is 98.20554649265905%
#
#  [[1589    4]
#  [  29  217]]

# %% [markdown]
# # K-Nearest Neighbors algorithm

# %%
#KNN = KNeighborsClassifier(metric = 'euclidean')
KNN = KNeighborsClassifier()
KNN.fit(x_train_df, train_set.Category)
predicted_values_KNN = KNN.predict(x_test_df)
print(predicted_values_KNN)
accuracy_KNN = accuracy_score(test_set.Category, predicted_values_KNN)
predictions['K-Nearest Neighbors algorithm'] = accuracy_KNN * 100
print("\nThe accuracy of K-Nearest Neighbors algorithm is {}%".format(accuracy_KNN * 100))
confusion_matrix_KNN = confusion_matrix(test_set.Category, predicted_values_KNN)
print("\n", confusion_matrix_KNN)
skplt.metrics.plot_confusion_matrix(test_set.Category, predicted_values_KNN, normalize = True)
plt.show()
# Out:
# ['ham' 'ham' 'ham' ... 'ham' 'ham' 'ham']
#
# The accuracy of K-Nearest Neighbors algorithm is 89.55954323001632%
#
#  [[1593    0]
#  [ 192   54]]

# %% [markdown]
# # Decision Tree learning

# %%
DT = DecisionTreeClassifier()
DT.fit(x_train_df, train_set.Category)
predicted_values_DT = DT.predict(x_test_df)
print(predicted_values_DT)
accuracy_DT = accuracy_score(test_set.Category, predicted_values_DT)
predictions['Decision Tree learning'] = accuracy_DT * 100
print("\nThe accuracy of Decision Tree learning is {}%".format(accuracy_DT * 100))
confusion_matrix_DT = confusion_matrix(test_set.Category, predicted_values_DT)
print("\n", confusion_matrix_DT)
skplt.metrics.plot_confusion_matrix(test_set.Category, predicted_values_DT, normalize = True)
plt.show()
# Out:
# ['ham' 'ham' 'ham' ... 'ham' 'ham' 'ham']
#
# The accuracy of Decision Tree learning is 96.90048939641109%
#
#  [[1584    9]
#  [  48  198]]

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
SVM = svm.SVC()
SVM.fit(x_train_df, train_set.Category)
predicted_values_SVM = SVM.predict(x_test_df)
print(predicted_values_SVM)
accuracy_SVM = accuracy_score(test_set.Category, predicted_values_SVM)
predictions['Support Vector Machine (SVM)'] = accuracy_SVM * 100
print("\nThe accuracy of Support Vector Machine (SVM) is {}%".format(accuracy_SVM * 100))
confusion_matrix_SVM = confusion_matrix(test_set.Category, predicted_values_SVM)
print("\n", confusion_matrix_SVM)
skplt.metrics.plot_confusion_matrix(test_set.Category, predicted_values_SVM, normalize = True)
plt.show()
# Out:
# ['ham' 'ham' 'ham' ... 'ham' 'ham' 'ham']
#
# The accuracy of Support Vector Machine (SVM) is 94.67101685698749%
#
#  [[1593    0]
#  [  98  148]]

# %% [markdown]
# # Random Forest

# %%
RF = RandomForestClassifier(n_estimators = 100, oob_score = True, random_state = 123456)
RF.fit(x_train_df, train_set.Category)
predicted_values_RF = RF.predict(x_test_df)
print(predicted_values_RF)
accuracy_RF = accuracy_score(test_set.Category, predicted_values_RF)
predictions['Random Forest'] = accuracy_RF * 100
print("\nThe accuracy of Random Forest is {}%".format(accuracy_RF * 100))
confusion_matrix_RF = confusion_matrix(test_set.Category, predicted_values_RF)
print("\n", confusion_matrix_RF)
skplt.metrics.plot_confusion_matrix(test_set.Category, predicted_values_RF, normalize = True)
plt.show()
# Out:
# ['ham' 'ham' 'ham' ... 'ham' 'ham' 'ham']
#
# The accuracy of Random Forest is 96.46547036432844%
#
#  [[1593    0]
#  [  65  181]]

# %% [markdown]
# # Method Comparison

# %%
fig, (ax1) = plt.subplots(ncols = 1, sharey = True,figsize = (15,5))
df = pd.DataFrame(list(predictions.items()),columns = ['Algorithms','Percentage'])
display(df)
sns.pointplot(x = "Algorithms", y = "Percentage", data = df,ax = ax1);
# Out:
#                       Algorithms  Percentage
# 0                    Naive Bayes   98.205546
# 1  K-Nearest Neighbors algorithm   89.559543
# 2         Decision Tree learning   96.954867
# 3   Support Vector Machine (SVM)   94.671017
# 4                  Random Forest   96.465470

# %% [markdown]
# # ROC Accuracy

# %%
#pr, tpr, thresholds = roc_curve(testset.v1,predicted_values_XGB, pos_label=2)
test_prediction = test_set.Category.tolist()
predicted_values = predicted_values_NB.tolist()
test_prediction = [1 if pred=="spam" else 0 for pred in test_prediction]
predicted_values = [1 if pred=="spam" else 0 for pred in predicted_values]
fpr, tpr, thresholds = roc_curve(test_prediction,predicted_values)
roc_auc = auc(fpr, tpr)
print("The ROC Accuracy is {}".format(roc_auc))
# Out:
# The ROC Accuracy is 0.9398014177881892

# %%
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
